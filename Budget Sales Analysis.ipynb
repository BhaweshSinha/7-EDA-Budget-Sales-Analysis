# %% [markdown]
# # Importing libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading all required spreadsheets from the workbook.

# %%
exc = pd.ExcelFile('AdventureWorks_Database.xlsx')
df_Calender = pd.read_excel(exc,'Calender')
df_Customers = pd.read_excel(exc,'Customers')
df_Products = pd.read_excel(exc,'Product')
df_Sales = pd.read_excel(exc,'Sales')

# %% [markdown]
# ### Showing Columns of all spreadsheets

# %%
df_Calender.columns
# Out:
# Index(['Date', 'DateKey', 'Year', 'Quarter', 'MonthNum', 'Month', 'FiscalYear',
#        'FiscalQuarter', 'FiscalMonthNum', 'FiscalMonth', 'MonthYear',
#        'MonthYearLong', 'MonthYearNum', 'WeekdayNum', 'Weekday',
#        'WeekdayWeekend'],
#       dtype='object')

# %%
df_Customers.columns
# Out:
# Index(['CustomerKey', 'FirstName', 'LastName', 'FullName', 'BirthDate',
#        'MaritalStatus', 'Gender', 'YearlyIncome', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HouseOwnerFlag',
#        'NumberCarsOwned', 'AddressLine1', 'DateFirstPurchase',
#        'CommuteDistance'],
#       dtype='object')

# %%
df_Products.columns
# Out:
# Index(['ProductKey', 'ProductName', 'SubCategory', 'Category', 'StandardCost',
#        'Color', 'ListPrice', 'DaysToManufacture', 'ProductLine', 'ModelName',
#        'Photo', 'ProductDescription', 'StartDate'],
#       dtype='object')

# %%
df_Sales.columns
# Out:
# Index(['ProductKey', 'OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey',
#        'SalesTerritoryKey', 'SalesOrderNumber', 'SalesOrderLineNumber',
#        'OrderQuantity', 'UnitPrice', 'TotalProductCost', 'SalesAmount',
#        'TaxAmt', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'StandardCost',
#        'List Price', 'Unnamed: 22', 'diif std cost', 'diff list price'],
#       dtype='object')

# %% [markdown]
# # Exploring and Visualizing the Customer budget data.

# %%
df_Customers.head()
# Out:
#    CustomerKey  FirstName LastName            FullName  BirthDate  \
# 0        11000        Jon     Yang           Yang, Jon 1966-04-08
# 1        11001     Eugene    Huang       Huang, Eugene 1965-05-14
# 2        11002      Ruben   Torres       Torres, Ruben 1965-08-12
# 3        11003    Christy      Zhu        Zhu, Christy 1968-02-15
# 4        11004  Elizabeth  Johnson  Johnson, Elizabeth 1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M         90000              2                     0
# 1             S      M         60000              3                     3
# 2             M      M         60000              3                     3
# 3             S      F         70000              0                     0
# 4             S      F         80000              5                     5
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned  \
# ...

# %%
df_Customers.tail()
# Out:
#        CustomerKey FirstName LastName        FullName  BirthDate  \
# 18479        29479     Tommy     Tang     Tang, Tommy 1958-07-04
# 18480        29480      Nina     Raji      Raji, Nina 1960-11-10
# 18481        29481      Ivan     Suri      Suri, Ivan 1960-01-05
# 18482        29482   Clayton    Zhang  Zhang, Clayton 1959-03-05
# 18483        29483     Jésus  Navarro  Navarro, Jésus 1959-12-08
#
#       MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 18479             M      M         30000              1                     0
# 18480             S      F         30000              3                     0
# 18481             S      M         30000              3                     0
# 18482             M      M         30000              3                     0
# 18483             M      M         30000              0                     0
#
#              Education Occupation  HouseOwnerFlag  NumberCarsOwned  \
# ...

# %%
df_Customers.shape
# Out:
# (18484, 17)

# %%
df_Customers.value_counts('Gender')
# Out:
# Gender
# M    9351
# F    9133
# Name: count, dtype: int64

# %%
plt.pie(df_Customers['Gender'].value_counts(),labels=['Male','Female'])
plt.title('Gender')
plt.show()

# %%
df_Customers.value_counts('MaritalStatus')
# Out:
# MaritalStatus
# M    10011
# S     8473
# Name: count, dtype: int64

# %%
plt.pie(df_Customers['MaritalStatus'].value_counts(),labels=['Married','Unmarried'])
plt.title('Marital Status')
plt.show()

# %%
df_Customers.value_counts('YearlyIncome')
# Out:
# YearlyIncome
# 60000     3127
# 40000     2747
# 70000     2349
# 30000     2287
# 20000     1767
# 80000     1342
# 10000     1155
# 90000      842
# 50000      670
# 100000     571
# 130000     512
# 110000     474
# 120000     332
# 170000     112
# 150000     103
# 160000      94
# Name: count, dtype: int64

# %%
sns.displot(df_Customers['YearlyIncome'],bins=20,kde=True)
plt.title('Average Yearly Income')
plt.show()

# %%
df_Customers.value_counts('TotalChildren')
# Out:
# TotalChildren
# 0    5165
# 2    3779
# 1    3619
# 4    2303
# 3    2194
# 5    1424
# Name: count, dtype: int64

# %%
lis = ['No child','Two Child','One Child','Four Child','Three Child','Five Child']
plt.pie(df_Customers['TotalChildren'].value_counts(),labels=lis)
plt.title('Number of Childrens they have')
plt.show()

# %%
df_Customers.value_counts('Education')
# Out:
# Education
# Bachelors              5356
# Partial College        5064
# High School            3294
# Graduate Degree        3189
# Partial High School    1581
# Name: count, dtype: int64

# %%
sns.countplot(df_Customers['Education'])
plt.title('Their Educational Qualification')
plt.show()

# %%
df_Customers.value_counts('NumberChildrenAtHome')
# Out:
# NumberChildrenAtHome
# 0    11116
# 1     2460
# 2     1648
# 3     1204
# 4     1089
# 5      967
# Name: count, dtype: int64

# %%
ath = [f'{x} Children' for x in range(6)]
plt.pie(df_Customers['NumberChildrenAtHome'].value_counts(),labels=ath)
plt.title('Number of Childrens stays at home')
plt.show()

# %%
df_Customers['Occupation'].value_counts()
# Out:
# Occupation
# Professional      5520
# Skilled Manual    4577
# Management        3075
# Clerical          2928
# Manual            2384
# Name: count, dtype: int64

# %%
sns.countplot(df_Customers['Occupation'])
plt.title('Occupaton they have')
plt.show()

# %%
df_Customers['HouseOwnerFlag'].value_counts()
# Out:
# HouseOwnerFlag
# 1    12502
# 0     5982
# Name: count, dtype: int64

# %%
plt.pie(df_Customers['HouseOwnerFlag'].value_counts(),labels=['Yes','No'])
plt.title('House Ownership')
plt.show()

# %%
df_Customers['NumberCarsOwned'].value_counts()
# Out:
# NumberCarsOwned
# 2    6457
# 1    4883
# 0    4238
# 3    1645
# 4    1261
# Name: count, dtype: int64

# %%
plt.pie(df_Customers['NumberCarsOwned'].value_counts(),labels=['2 Cars','1 Cars','0 Cars','3 Cars','4 Cars'])
plt.title('Number of Cars Owned by the Customers')
plt.show()

# %%
df_Customers['CommuteDistance'].value_counts()
# Out:
# CommuteDistance
# 0-1 Miles     6310
# 2-5 Miles     3234
# 1-2 Miles     3232
# 5-10 Miles    3214
# 10+ Miles     2494
# Name: count, dtype: int64

# %%
dist = ['0-1 Miles','2-5 Miles','1-2 Miles','5-10 Miles','10+ Miles']
plt.pie(df_Customers['CommuteDistance'].value_counts(),labels=dist)
plt.title('Commute Distance')
plt.show()

# %% [markdown]
# # Exploring and Visualizing the Products Data.

# %%
df_Products.head(5)
# Out:
#    ProductKey            ProductName SubCategory Category  StandardCost Color  \
# 0           1        Adjustable Race         NaN      NaN           NaN   NaN
# 1           2           Bearing Ball         NaN      NaN           NaN   NaN
# 2           3        BB Ball Bearing         NaN      NaN           NaN   NaN
# 3           4  Headset Ball Bearings         NaN      NaN           NaN   NaN
# 4           5                  Blade         NaN      NaN           NaN   NaN
#
#    ListPrice  DaysToManufacture ProductLine ModelName  \
# 0        NaN                  0         NaN       NaN
# 1        NaN                  0         NaN       NaN
# 2        NaN                  1         NaN       NaN
# 3        NaN                  0         NaN       NaN
# 4        NaN                  1         NaN       NaN
#
#                                                Photo ProductDescription  \
# 0  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# ...

# %%
df_Products.tail(5)
# Out:
#      ProductKey         ProductName      SubCategory    Category  \
# 601         602   ML Bottom Bracket  Bottom Brackets  Components
# 602         603   HL Bottom Bracket  Bottom Brackets  Components
# 603         604  Road-750 Black, 44       Road Bikes       Bikes
# 604         605  Road-750 Black, 48       Road Bikes       Bikes
# 605         606  Road-750 Black, 52       Road Bikes       Bikes
#
#      StandardCost  Color  ListPrice  DaysToManufacture ProductLine  \
# 601       44.9506    NaN     101.24                  1         NaN
# 602       53.9416    NaN     121.49                  1         NaN
# 603      343.6496  Black     539.99                  4        Road
# 604      343.6496  Black     539.99                  4        Road
# 605      343.6496  Black     539.99                  4        Road
#
#              ModelName                                              Photo  \
# 601  ML Bottom Bracket  http://www.avising.com/me/LearnPBI/DataSources...
# ...

# %%
df_Products.shape
# Out:
# (606, 13)

# %%
df_Products.isna().sum()
# Out:
# ProductKey              0
# ProductName             0
# SubCategory           209
# Category              209
# StandardCost          211
# Color                 254
# ListPrice             211
# DaysToManufacture       0
# ProductLine           226
# ModelName             209
# Photo                   0
# ProductDescription    210
# StartDate               0
# dtype: int64

# %%
df_Products.dropna(inplace=True)

# %%
df_Products.isna().sum()
# Out:
# ProductKey            0
# ProductName           0
# SubCategory           0
# Category              0
# StandardCost          0
# Color                 0
# ListPrice             0
# DaysToManufacture     0
# ProductLine           0
# ModelName             0
# Photo                 0
# ProductDescription    0
# StartDate             0
# dtype: int64

# %%
df_Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331 entries, 211 to 605
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ProductKey          331 non-null    int64
#  1   ProductName         331 non-null    object
#  2   SubCategory         331 non-null    object
#  3   Category            331 non-null    object
#  4   StandardCost        331 non-null    float64
#  5   Color               331 non-null    object
#  6   ListPrice           331 non-null    float64
#  7   DaysToManufacture   331 non-null    int64
#  8   ProductLine         331 non-null    object
#  9   ModelName           331 non-null    object
#  10  Photo               331 non-null    object
#  11  ProductDescription  331 non-null    object
#  12  StartDate           331 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 36.2+ KB

# %%
df_Products.head()
# Out:
#      ProductKey              ProductName SubCategory     Category  \
# 211         212    Sport-100 Helmet, Red     Helmets  Accessories
# 212         213    Sport-100 Helmet, Red     Helmets  Accessories
# 213         214    Sport-100 Helmet, Red     Helmets  Accessories
# 214         215  Sport-100 Helmet, Black     Helmets  Accessories
# 215         216  Sport-100 Helmet, Black     Helmets  Accessories
#
#      StandardCost  Color  ListPrice  DaysToManufacture ProductLine  ModelName  \
# 211       12.0278    Red    33.6442                  0       Sport  Sport-100
# 212       13.8782    Red    33.6442                  0       Sport  Sport-100
# 213       13.0863    Red    34.9900                  0       Sport  Sport-100
# 214       12.0278  Black    33.6442                  0       Sport  Sport-100
# 215       13.8782  Black    33.6442                  0       Sport  Sport-100
#
#                                                  Photo  \
# ...

# %%
df_Products.tail()
# Out:
#      ProductKey             ProductName     SubCategory Category  \
# 598         599  Mountain-500 Black, 48  Mountain Bikes    Bikes
# 599         600  Mountain-500 Black, 52  Mountain Bikes    Bikes
# 603         604      Road-750 Black, 44      Road Bikes    Bikes
# 604         605      Road-750 Black, 48      Road Bikes    Bikes
# 605         606      Road-750 Black, 52      Road Bikes    Bikes
#
#      StandardCost  Color  ListPrice  DaysToManufacture ProductLine  \
# 598      294.5797  Black     539.99                  4    Mountain
# 599      294.5797  Black     539.99                  4    Mountain
# 603      343.6496  Black     539.99                  4        Road
# 604      343.6496  Black     539.99                  4        Road
# 605      343.6496  Black     539.99                  4        Road
#
#         ModelName                                              Photo  \
# 598  Mountain-500  http://www.avising.com/me/LearnPBI/DataSources...
# ...

# %%
df_Products.shape
# Out:
# (331, 13)

# %%
df_Products.value_counts('SubCategory')
# Out:
# SubCategory
# Road Frames        68
# Road Bikes         65
# Mountain Frames    40
# Mountain Bikes     38
# Touring Bikes      22
# Touring Frames     18
# Jerseys            16
# Wheels             14
# Gloves              9
# Helmets             9
# Shorts              7
# Pedals              7
# Socks               4
# Caps                3
# Tights              3
# Vests               3
# Bib-Shorts          3
# Panniers            1
# Hydration Packs     1
# Name: count, dtype: int64

# %%
sns.countplot(df_Products['SubCategory'].values)
plt.title('Sub-Category of the Product')
plt.show()

# %%
df_Products.value_counts('Category')
# Out:
# Category
# Components     147
# Bikes          125
# Clothing        48
# Accessories     11
# Name: count, dtype: int64

# %%
sns.countplot(df_Products['Category'].values)
plt.title('Category of the Product')
plt.show()

# %%
df_Products.value_counts('Color')
# Out:
# Color
# Black           125
# Red              62
# Yellow           46
# Silver           40
# Blue             28
# Multi            18
# Silver/Black      7
# White             4
# Grey              1
# Name: count, dtype: int64

# %%
sns.countplot(df_Products['Color'].values)
plt.title('Color of the Product')
plt.show()

# %%
df_Products.value_counts('ProductLine')
# Out:
# ProductLine
# Road        144
# Mountain     95
# Sport        48
# Touring      44
# Name: count, dtype: int64

# %%
sns.countplot(df_Products['ProductLine'].values)
plt.title('Line of the Product')
plt.show()

# %%
sns.displot(df_Products['StandardCost'],kde=True)
plt.title('Standard cost Distribution')
plt.show()

# %%
sns.displot(df_Products['ListPrice'],kde=True)
plt.title('List Price Distribution')
plt.show()

# %%
sns.scatterplot(x=df_Products['ListPrice'],y=df_Products['StandardCost'])
plt.title('Standard cost vs List Price')
plt.show()

# %%
df_Products.head()
# Out:
#      ProductKey              ProductName SubCategory     Category  \
# 211         212    Sport-100 Helmet, Red     Helmets  Accessories
# 212         213    Sport-100 Helmet, Red     Helmets  Accessories
# 213         214    Sport-100 Helmet, Red     Helmets  Accessories
# 214         215  Sport-100 Helmet, Black     Helmets  Accessories
# 215         216  Sport-100 Helmet, Black     Helmets  Accessories
#
#      StandardCost  Color  ListPrice  DaysToManufacture ProductLine  ModelName  \
# 211       12.0278    Red    33.6442                  0       Sport  Sport-100
# 212       13.8782    Red    33.6442                  0       Sport  Sport-100
# 213       13.0863    Red    34.9900                  0       Sport  Sport-100
# 214       12.0278  Black    33.6442                  0       Sport  Sport-100
# 215       13.8782  Black    33.6442                  0       Sport  Sport-100
#
#                                                  Photo  \
# ...

# %%
df_Products.tail()
# Out:
#      ProductKey             ProductName     SubCategory Category  \
# 598         599  Mountain-500 Black, 48  Mountain Bikes    Bikes
# 599         600  Mountain-500 Black, 52  Mountain Bikes    Bikes
# 603         604      Road-750 Black, 44      Road Bikes    Bikes
# 604         605      Road-750 Black, 48      Road Bikes    Bikes
# 605         606      Road-750 Black, 52      Road Bikes    Bikes
#
#      StandardCost  Color  ListPrice  DaysToManufacture ProductLine  \
# 598      294.5797  Black     539.99                  4    Mountain
# 599      294.5797  Black     539.99                  4    Mountain
# 603      343.6496  Black     539.99                  4        Road
# 604      343.6496  Black     539.99                  4        Road
# 605      343.6496  Black     539.99                  4        Road
#
#         ModelName                                              Photo  \
# 598  Mountain-500  http://www.avising.com/me/LearnPBI/DataSources...
# ...

# %%
df_Products.reset_index()
# Out:
#      index  ProductKey              ProductName     SubCategory     Category  \
# 0      211         212    Sport-100 Helmet, Red         Helmets  Accessories
# 1      212         213    Sport-100 Helmet, Red         Helmets  Accessories
# 2      213         214    Sport-100 Helmet, Red         Helmets  Accessories
# 3      214         215  Sport-100 Helmet, Black         Helmets  Accessories
# 4      215         216  Sport-100 Helmet, Black         Helmets  Accessories
# ..     ...         ...                      ...             ...          ...
# 326    598         599   Mountain-500 Black, 48  Mountain Bikes        Bikes
# 327    599         600   Mountain-500 Black, 52  Mountain Bikes        Bikes
# 328    603         604       Road-750 Black, 44      Road Bikes        Bikes
# 329    604         605       Road-750 Black, 48      Road Bikes        Bikes
# 330    605         606       Road-750 Black, 52      Road Bikes        Bikes
#
# ...

# %% [markdown]
# # Exploring and Visualizing the Sales budget data.

# %%
df_Sales.head(5)
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         346 2014-01-01 2014-01-08        28389             1
# 2         346 2014-01-01 2014-01-08        25863             1
# 3         336 2014-01-01 2014-01-08        14501             1
# 4         346 2014-01-01 2014-01-08        11003             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  7          SO43698                     1              2
# 2                  1          SO43699                     1              2
# 3                  4          SO43700                     1              2
# 4                  9          SO43701                     1              2
#
#    UnitPrice  ...  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
df_Sales.shape
# Out:
# (58189, 25)

# %%
df_Sales.isna().sum()
# Out:
# ProductKey                  0
# OrderDate                   0
# ShipDate                    0
# CustomerKey                 0
# PromotionKey                0
# SalesTerritoryKey           0
# SalesOrderNumber            0
# SalesOrderLineNumber        0
# OrderQuantity               0
# UnitPrice                   0
# TotalProductCost            0
# SalesAmount                 0
# TaxAmt                      0
# Unnamed: 13             58189
# Unnamed: 14             58189
# Unnamed: 15                 0
# Unnamed: 16                 0
# Unnamed: 17             58189
# Unnamed: 18                 0
# Unnamed: 19             58189
# StandardCost                0
# List Price                  0
# Unnamed: 22             58189
# diif std cost               0
# diff list price             0
# dtype: int64

# %%
# ?df_Sales.drop
for i in range(13,20):
    df_Sales.drop(f'Unnamed: {i}',axis=1,inplace=True)
df_Sales.drop('Unnamed: 22',axis=1,inplace=True)

# %%
df_Sales.head(5)
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         346 2014-01-01 2014-01-08        28389             1
# 2         346 2014-01-01 2014-01-08        25863             1
# 3         336 2014-01-01 2014-01-08        14501             1
# 4         346 2014-01-01 2014-01-08        11003             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  7          SO43698                     1              2
# 2                  1          SO43699                     1              2
# 3                  4          SO43700                     1              2
# 4                  9          SO43701                     1              2
#
#    UnitPrice  TotalProductCost  SalesAmount    TaxAmt  StandardCost  \
# ...

# %%
df_Sales.columns
# Out:
# Index(['ProductKey', 'OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey',
#        'SalesTerritoryKey', 'SalesOrderNumber', 'SalesOrderLineNumber',
#        'OrderQuantity', 'UnitPrice', 'TotalProductCost', 'SalesAmount',
#        'TaxAmt', 'StandardCost', 'List Price', 'diif std cost',
#        'diff list price'],
#       dtype='object')

# %%
df_Sales.value_counts('diif std cost')
# Out:
# diif std cost
# 0    58189
# Name: count, dtype: int64

# %%
df_Sales.value_counts('diff list price')
# Out:
# diff list price
# 0    58189
# Name: count, dtype: int64

# %%
df_Sales.drop('diif std cost',axis=1,inplace=True)
df_Sales.drop('diff list price',axis=1,inplace=True)

# %%
df_Sales.shape
# Out:
# (58189, 15)

# %%
df_Sales.columns
# Out:
# Index(['ProductKey', 'OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey',
#        'SalesTerritoryKey', 'SalesOrderNumber', 'SalesOrderLineNumber',
#        'OrderQuantity', 'UnitPrice', 'TotalProductCost', 'SalesAmount',
#        'TaxAmt', 'StandardCost', 'List Price'],
#       dtype='object')

# %%
df_Sales.head()
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         346 2014-01-01 2014-01-08        28389             1
# 2         346 2014-01-01 2014-01-08        25863             1
# 3         336 2014-01-01 2014-01-08        14501             1
# 4         346 2014-01-01 2014-01-08        11003             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  7          SO43698                     1              2
# 2                  1          SO43699                     1              2
# 3                  4          SO43700                     1              2
# 4                  9          SO43701                     1              2
#
#    UnitPrice  TotalProductCost  SalesAmount    TaxAmt  StandardCost  \
# ...

# %%
df_Sales.value_counts('ProductKey')
# Out:
# ProductKey
# 477    4076
# 480    3010
# 528    2908
# 529    2216
# 214    2150
#        ...
# 320      19
# 332      18
# 340      17
# 322      17
# 324      16
# Name: count, Length: 158, dtype: int64

# %%
df_Sales.value_counts('PromotionKey')
# Out:
# PromotionKey
# 1     56038
# 2      2118
# 13       20
# 14       13
# Name: count, dtype: int64

# %%
#Average Customer Retention rate
df_Sales.value_counts('CustomerKey').mean()
# Out:
# 3.2475164638910594

# %%
df_Sales.value_counts('SalesTerritoryKey')
# Out:
# SalesTerritoryKey
# 9     12972
# 4     11864
# 1      8579
# 6      7142
# 10     6709
# 8      5460
# 7      5382
# 5        34
# 2        27
# 3        20
# Name: count, dtype: int64

# %%
leb = ['9','4','1','6','10','8','7','5','2','3']
plt.pie(df_Sales['SalesTerritoryKey'].value_counts(),labels=leb)
plt.title('Count of Sales in different Territory')
plt.show()

# %%
df_Sales.value_counts('SalesOrderLineNumber')
# Out:
# SalesOrderLineNumber
# 1    26683
# 2    17258
# 3     9456
# 4     3855
# 5      800
# 6      120
# 7       14
# 8        3
# Name: count, dtype: int64

# %%
sns.displot(df_Sales['TotalProductCost'],kde=True,bins=10)
plt.title('Average Product Cost')
plt.show()

# %%
sns.displot(df_Sales['SalesAmount'],kde=True,bins=10)
plt.title('Average Sales Amount')
plt.show()

# %%
sns.displot(df_Sales['TaxAmt'],kde=True,bins=10)
plt.title('Average Tax Amount')
plt.show()

# %%
sns.displot(df_Sales['StandardCost'],kde=True,bins=10)
plt.title('Average Standard Cost')
plt.show()

# %%
sns.displot(df_Sales['List Price'],kde=True,bins=10)
plt.title('Average List Price')
plt.show()

# %%
sns.scatterplot(x=df_Sales['TotalProductCost'],y=df_Sales['SalesAmount'])
plt.title('Product cost vs Sales amount')
plt.show()

# %%
sns.scatterplot(x=df_Sales['TotalProductCost'],y=df_Sales['TaxAmt'])
plt.title('Product Cost vs Tax Amount')
plt.show()

# %%
sns.scatterplot(x=df_Sales['TotalProductCost'],y=df_Sales['StandardCost'])
plt.title('Product Cost vs Tax Amount')
plt.show()

# %%
sns.scatterplot(x=df_Sales['TotalProductCost'],y=df_Sales['List Price'])
plt.title('Product Cost vs List Price')
plt.show()

# %%
print(f'The Average Total Product cost = {df_Sales['TotalProductCost'].mean()}')
print(f'The Average Sales Amount = {df_Sales['SalesAmount'].mean()}')
print(f'The Average Tax Amount = {df_Sales['TaxAmt'].mean()}')
print(f'The Average Standard Cost = {df_Sales['StandardCost'].mean()}')
print(f'The Average List Price = {df_Sales['List Price'].mean()}')
# Out:
# The Average Total Product cost = 296.5391854697623
# The Average Sales Amount = 503.666270097441
# The Average Tax Amount = 40.293302509065285
# The Average Standard Cost = 296.5391854697623
# The Average List Price = 503.666270097441

# %%
df_Sales.describe()
# Out:
#          ProductKey                      OrderDate  \
# count  58189.000000                          58189
# mean     437.208304  2016-06-03 03:56:09.605939200
# min      214.000000            2014-01-01 00:00:00
# 25%      358.000000            2016-04-01 00:00:00
# 50%      479.000000            2016-07-07 00:00:00
# 75%      529.000000            2016-10-10 00:00:00
# max      606.000000            2016-12-30 00:00:00
# std      118.099746                            NaN
#
#                             ShipDate   CustomerKey  PromotionKey  \
# count                          58189  58189.000000  58189.000000
# mean   2016-06-10 04:03:24.657237760  18853.004640      1.043427
# min              2014-01-08 00:00:00  11000.000000      1.000000
# 25%              2016-04-08 00:00:00  14012.000000      1.000000
# 50%              2016-07-14 00:00:00  18151.000000      1.000000
# 75%              2016-10-17 00:00:00  23450.000000      1.000000
# ...

# %%
print(f'The Least Total Product cost = {df_Sales['TotalProductCost'].min()}')
print(f'The Least Sales Amount = {df_Sales['SalesAmount'].min()}')
print(f'The Least Tax Amount = {df_Sales['TaxAmt'].min()}')
print(f'The Least Standard Cost = {df_Sales['StandardCost'].min()}')
print(f'The Least List Price = {df_Sales['List Price'].min()}')
# Out:
# The Least Total Product cost = 0.8565
# The Least Sales Amount = 2.29
# The Least Tax Amount = 0.1832
# The Least Standard Cost = 0.8565
# The Least List Price = 2.29

# %%
print(f'The Maximum Total Product cost = {df_Sales['TotalProductCost'].max()}')
print(f'The Maximum Sales Amount = {df_Sales['SalesAmount'].max()}')
print(f'The Maximum Tax Amount = {df_Sales['TaxAmt'].max()}')
print(f'The Maximum Standard Cost = {df_Sales['StandardCost'].max()}')
print(f'The Maximum List Price = {df_Sales['List Price'].max()}')
# Out:
# The Maximum Total Product cost = 2171.2942
# The Maximum Sales Amount = 3578.27
# The Maximum Tax Amount = 286.2616
# The Maximum Standard Cost = 2171.2942
# The Maximum List Price = 3578.27

# %%
df_Sales.value_counts('OrderQuantity')
# Out:
# OrderQuantity
# 1    41585
# 2     8340
# 4     8264
# Name: count, dtype: int64

# %%
plt.pie(df_Sales['OrderQuantity'].value_counts(),labels=['1 Unit','2 Units','4 Units'])
plt.title('Order Quantity')
plt.show()
